# %%
#1. Perform the following operations using R/Python on suitable data sets:
#a) read data from different formats (like csv, xls)
#b) indexing and selecting data, sort data,
#c) describe attributes of data, checking data types of each column,
#d) counting unique values of data, format of each column, converting variable data type (e.g.from long to short, vice versa),
#e) identifying missing values and fill in the missing values

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#a)Reading data from excel
customers=pd.read_excel("/content/Customers.xlsx")
customers
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
#a)Reading data from csv
customer=pd.read_csv("/content/Customers - Customers.csv")
customer
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
#indexing(using colname)
customers["Gender"]
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3       Female
# 4       Female
#          ...
# 1995    Female
# 1996    Female
# 1997      Male
# 1998      Male
# 1999      Male
# Name: Gender, Length: 2000, dtype: object

# %%
#indexing(using row index)
customers.loc[2]
# Out:
# CustomerID                       3
# Gender                      Female
# Age                             20
# Annual Income ($)            86000
# Spending Score (1-100)           6
# Profession                Engineer
# Work Experience                  1
# Family Size                      1
# Name: 2, dtype: object

# %%
#indexing(using iloc)
customers.iloc[0:2,2:5]
# Out:
#    Age  Annual Income ($)  Spending Score (1-100)
# 0   19              15000                      39
# 1   21              35000                      81

# %%
#Checking datatypes of each column
#format of each col
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
#sorting by axis
customers.sort_index(axis=1)#in ascending order
# Out:
#       Age  Annual Income ($)  CustomerID  Family Size  Gender     Profession  \
# 0      19              15000           1            4    Male     Healthcare
# 1      21              35000           2            3    Male       Engineer
# 2      20              86000           3            1  Female       Engineer
# 3      23              59000           4            2  Female         Lawyer
# 4      31              38000           5            6  Female  Entertainment
# ...   ...                ...         ...          ...     ...            ...
# 1995   71             184387        1996            7  Female         Artist
# 1996   91              73158        1997            7  Female         Doctor
# 1997   87              90961        1998            2    Male     Healthcare
# 1998   77             182109        1999            2    Male      Executive
# 1999   90             110610        2000            2    Male  Entertainment
#
# ...

# %%
#sorting by value
customers.sort_values("Age",axis=0)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 443          444  Female    0              68761                      16
# 466          467    Male    0             186002                      80
# 1271        1272  Female    0              61228                      81
# 1248        1249  Female    0             143082                      63
# 1583        1584  Female    0             120899                       7
# ...          ...     ...  ...                ...                     ...
# 1629        1630    Male   99             162762                      52
# 1188        1189  Female   99             122548                      14
# 351          352    Male   99             173394                       4
# 361          362    Male   99              63364                      61
# 347          348  Female   99             184426                      41
#
#          Profession  Work Experience  Family Size
# ...

# %%
#Describing attributes of data
customers.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
#counting unique values of data
customers.value_counts()
# Out:
# CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  Profession     Work Experience  Family Size
# 1           Male    19   15000              39                      Healthcare     1                4              1
# 1346        Male    36   75178              41                      Entertainment  1                7              1
# 1344        Female  82   157994             92                      Artist         1                1              1
# 1343        Female  45   114741             96                      Artist         0                5              1
# 1342        Male    38   76103              62                      Executive      9                3              1
#                                                                                                                   ..
# 662         Male    53   148759             52                      Doctor         7                7              1
# ...

# %%
#converting variable datatype
customers['Age'].astype(float) #int to float
# Out:
# 0       19.0
# 1       21.0
# 2       20.0
# 3       23.0
# 4       31.0
#         ...
# 1995    71.0
# 1996    91.0
# 1997    87.0
# 1998    77.0
# 1999    90.0
# Name: Age, Length: 2000, dtype: float64

# %%
#Idetifying missing values and fill in the missing values
customer.isnull()#Since there aren't any missing values and hence nothing can be filled in
# Out:
#       CustomerID  Gender    Age  Annual Income ($)  Spending Score (1-100)  \
# 0          False   False  False              False                   False
# 1          False   False  False              False                   False
# 2          False   False  False              False                   False
# 3          False   False  False              False                   False
# 4          False   False  False              False                   False
# ...          ...     ...    ...                ...                     ...
# 1995       False   False  False              False                   False
# 1996       False   False  False              False                   False
# 1997       False   False  False              False                   False
# 1998       False   False  False              False                   False
# 1999       False   False  False              False                   False
#
#       Profession  Work Experience  Family Size
# ...
